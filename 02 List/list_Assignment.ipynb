# %%
l = [10,20,30,40,50]

# %%
l = [10,20,30,40,50]
sum = 0

for i in l:
    sum+=i
print("Sum of list: ",sum)
# Out:
# Sum of list:  150

# %%
small = l[0]
for i in l:
    if i in l:
        if i<small:
            small = i

print("Smallest number: ",small)
# Out:
# Smallest number:  10

# %%
s = input("Enter String: ")
unique = []

for ch in s:
    if ch not in unique:
        unique.append(ch)

print(unique)
# Out:
# ['b', 'a', 'n']

# %%
l = ['Red', 'Green', 'White', 'Black', 'Pink', 'Yellow'] 

new_list = [l[i] for i in range(len(l)) if i not in (0,4,5)]
new_list
# Out:
# ['Green', 'White', 'Black']

# %%
l =  [1, 1, 2, 3, 4, 4, 5, 1]
unique = []

for i in range(len(l)):
    c = 0
    for j in range(len(l)):
        if l[i] == l[j]:
            c+=1

    if c == 1:
        unique.append(l[i])
    # if l.count(i) == 1:
    #     unique.append(i)
print(unique)
# Out:
# [2, 3, 5]

# %%
l =  [1, 1, 2, 3, 4, 4, 5, 1]
unique = []

for i in l:
    if i not in unique:
        unique.append(i)

print(unique)
# Out:
# [1, 2, 3, 4, 5]

# %%
l = [1, 1, 2, 3, 4, 4, 5, 1]
l.insert(2,12)
l
# Out:
# [1, 1, 12, 2, 3, 4, 4, 5, 1]

# %%
l =  ['Red', 'Green', 'White', 'Black', 'Pink', 'Yellow']
r = []
for i in range(len(l)-1,-1,-1):
    r.append(l[i][::-1])

r
# Out:
# ['wolleY', 'kniP', 'kcalB', 'etihW', 'neerG', 'deR']

# %%
l = ['level','hello','1221','789','wow']
p = []
for i in l:
    rev = ''
    for ch in i:
        rev = ch + rev

    if i == rev:
        p.append(i)
    # if i==i[::-1]:
    #     p.append(i)

p
# Out:
# ['level', '1221', 'wow']

# %%
l = [1,2,3,5,6,9,77]

start = 3
end = 5

square = []

for i in range(start,end+1):
    square.append(l[i]**2)

square
# Out:
# [25, 36, 81]

# %%
e = [i for i in l if i%2==0]
e
# Out:
# [2, 6]

# %%
l = [10, 20, 30, 40, 50, 60]

index = 3

l = l[index:]

print(l)
# Out:
# [40, 50, 60]
